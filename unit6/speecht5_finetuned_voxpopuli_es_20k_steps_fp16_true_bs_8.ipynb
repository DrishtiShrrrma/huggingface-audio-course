# %%
# !pip install soundfile speechbrain accelerate datasets
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Collecting speechbrain
#   Downloading speechbrain-0.5.15-py3-none-any.whl (553 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.8/553.8 kB 8.6 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 28.9 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.14.2-py3-none-any.whl (518 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 kB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.15.1)
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from speechbrain) (23.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.10.1)
# Collecting sentencepiece (from speechbrain)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.0.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.0.2+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from speechbrain) (4.65.0)
# Collecting huggingface-hub (from speechbrain)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 2.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->speechbrain) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->speechbrain) (16.0.6)
# Collecting ruamel.yaml<=0.17.28,>=0.17.8 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.17.28-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml<=0.17.28,>=0.17.8->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->speechbrain) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->speechbrain) (1.3.0)
# Installing collected packages: sentencepiece, xxhash, ruamel.yaml.clib, dill, ruamel.yaml, multiprocess, huggingface-hub, hyperpyyaml, datasets, speechbrain, accelerate
# Successfully installed accelerate-0.21.0 datasets-2.14.2 dill-0.3.7 huggingface-hub-0.16.4 hyperpyyaml-1.2.1 multiprocess-0.70.15 ruamel.yaml-0.17.28 ruamel.yaml.clib-0.2.7 sentencepiece-0.1.99 speechbrain-0.5.15 xxhash-3.3.0

# %%
# !pip install ipython-autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.19.0

# %%
# %load_ext autotime
# Out:
# time: 262 µs (started: 2023-08-01 19:26:50 +00:00)

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 54.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.8 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
# time: 28.2 s (started: 2023-08-01 19:26:50 +00:00)

# %%
# !pip install git+https://github.com/huggingface/accelerate
# Out:
# Collecting git+https://github.com/huggingface/accelerate
#   Cloning https://github.com/huggingface/accelerate to /tmp/pip-req-build-0273eshv
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/accelerate /tmp/pip-req-build-0273eshv
#   Resolved https://github.com/huggingface/accelerate to commit 0dec477985584f37e4abde0d6b7f6f47a2a3b9f5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.22.0.dev0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.22.0.dev0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.22.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.22.0.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.22.0.dev0) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.22.0.dev0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.22.0.dev0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.22.0.dev0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.22.0.dev0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.22.0.dev0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.22.0.dev0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.22.0.dev0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.22.0.dev0) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.22.0.dev0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.22.0.dev0) (1.3.0)
# Building wheels for collected packages: accelerate
#   Building wheel for accelerate (pyproject.toml) ... done
#   Created wheel for accelerate: filename=accelerate-0.22.0.dev0-py3-none-any.whl size=248303 sha256=edf3449b9769d47711a57d887dcbcc868b2a34700e6528913c2e711502851fea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1l4my2t_/wheels/f6/c7/9d/1b8a5ca8353d9307733bc719107acb67acdc95063bba749f26
# Successfully built accelerate
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
# Successfully installed accelerate-0.22.0.dev0
# time: 14.2 s (started: 2023-08-01 19:27:18 +00:00)

# %%
# !nvidia-smi
# Out:
# Tue Aug  1 19:27:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    41W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# time: 204 ms (started: 2023-08-01 19:27:32 +00:00)

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# time: 188 ms (started: 2023-08-01 19:27:34 +00:00)

# %%
from datasets import load_dataset, Audio

dataset = load_dataset("facebook/voxpopuli", "es", split="train")
len(dataset)
# Out:
# Downloading builder script:   0%|          | 0.00/8.84k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/22.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/722k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/706k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.81G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.87G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.85G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/337M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/633M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/629M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# 50922
# time: 16min 21s (started: 2023-08-01 19:28:01 +00:00)

# %%
from transformers import SpeechT5Processor

checkpoint = "microsoft/speecht5_tts"
processor = SpeechT5Processor.from_pretrained(checkpoint)
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/433 [00:00<?, ?B/s]
# Downloading spm_char.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/232 [00:00<?, ?B/s]
# time: 3.24 s (started: 2023-08-01 19:44:22 +00:00)

# %%
tokenizer = processor.tokenizer
# Out:
# time: 338 µs (started: 2023-08-01 19:44:26 +00:00)

# %%
def extract_all_chars(batch):
    all_text = " ".join(batch["normalized_text"])
    vocab = list(set(all_text))
    return {"vocab": [vocab], "all_text": [all_text]}


vocabs = dataset.map(
    extract_all_chars,
    batched=True,
    batch_size=-1,
    keep_in_memory=True,
    remove_columns=dataset.column_names,
)

dataset_vocab = set(vocabs["vocab"][0])
tokenizer_vocab = {k for k, _ in tokenizer.get_vocab().items()}
# Out:
# Map:   0%|          | 0/50922 [00:00<?, ? examples/s]
# time: 231 ms (started: 2023-08-01 19:44:26 +00:00)

# %%
dataset_vocab - tokenizer_vocab
# Out:
# {' ', '1', 'á', 'í', 'ñ', 'ó', 'ú', 'ü'}
# time: 1.98 ms (started: 2023-08-01 19:44:26 +00:00)

# %%
replacements = [
    ("1", "1"),
    ("á", "a"),
    ("í", "i"),
    ("ñ", "n"),
    ("ó", "o"),
    ("ú", "u"),
    ("ü", "u"),
]


def cleanup_text(inputs):
    for src, dst in replacements:
        inputs["normalized_text"] = inputs["normalized_text"].replace(src, dst)
    return inputs


dataset = dataset.map(cleanup_text)
# Out:
# Map:   0%|          | 0/50922 [00:00<?, ? examples/s]
# time: 5.82 s (started: 2023-08-01 19:54:05 +00:00)

# %%
from collections import defaultdict

speaker_counts = defaultdict(int)

for speaker_id in dataset["speaker_id"]:
    speaker_counts[speaker_id] += 1
# Out:
# time: 51.1 ms (started: 2023-08-01 19:54:13 +00:00)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(speaker_counts.values(), bins=20)
plt.ylabel("Speakers")
plt.xlabel("Examples")
plt.show()
# Out:
# time: 225 ms (started: 2023-08-01 19:54:15 +00:00)

# %%
def select_speaker(speaker_id):
    return 100 <= speaker_counts[speaker_id] <= 400


dataset = dataset.filter(select_speaker, input_columns=["speaker_id"])
# Out:
# Filter:   0%|          | 0/50922 [00:00<?, ? examples/s]
# time: 121 ms (started: 2023-08-01 19:54:17 +00:00)

# %%
len(set(dataset["speaker_id"]))
# Out:
# 60
# time: 62.7 ms (started: 2023-08-01 19:54:19 +00:00)

# %%
len(dataset)
# Out:
# 13154
# time: 2.53 ms (started: 2023-08-01 19:54:20 +00:00)

# %%
import os
import torch
from speechbrain.pretrained import EncoderClassifier

spk_model_name = "speechbrain/spkrec-xvect-voxceleb"

device = "cuda" if torch.cuda.is_available() else "cpu"
speaker_model = EncoderClassifier.from_hparams(
    source=spk_model_name,
    run_opts={"device": device},
    savedir=os.path.join("/tmp", spk_model_name),
)


def create_speaker_embedding(waveform):
    with torch.no_grad():
        speaker_embeddings = speaker_model.encode_batch(torch.tensor(waveform))
        speaker_embeddings = torch.nn.functional.normalize(speaker_embeddings, dim=2)
        speaker_embeddings = speaker_embeddings.squeeze().cpu().numpy()
    return speaker_embeddings
# Out:
# Downloading (…)ain/hyperparams.yaml:   0%|          | 0.00/2.04k [00:00<?, ?B/s]
# Downloading embedding_model.ckpt:   0%|          | 0.00/16.9M [00:00<?, ?B/s]
# Downloading mean_var_norm_emb.ckpt:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# Downloading classifier.ckpt:   0%|          | 0.00/15.9M [00:00<?, ?B/s]
# Downloading (…)in/label_encoder.txt:   0%|          | 0.00/129k [00:00<?, ?B/s]
# time: 12.4 s (started: 2023-08-01 19:54:21 +00:00)

# %%
def prepare_dataset(example):
    audio = example["audio"]

    example = processor(
        text=example["normalized_text"],
        audio_target=audio["array"],
        sampling_rate=audio["sampling_rate"],
        return_attention_mask=False,
    )

    # strip off the batch dimension
    example["labels"] = example["labels"][0]

    # use SpeechBrain to obtain x-vector
    example["speaker_embeddings"] = create_speaker_embedding(audio["array"])

    return example
# Out:
# time: 455 µs (started: 2023-08-01 19:54:34 +00:00)

# %%
processed_example = prepare_dataset(dataset[0])
list(processed_example.keys())
# Out:
# ['input_ids', 'labels', 'speaker_embeddings']
# time: 18.2 s (started: 2023-08-01 19:55:14 +00:00)

# %%
processed_example["speaker_embeddings"].shape
# Out:
# (512,)
# time: 2.2 ms (started: 2023-08-01 19:55:32 +00:00)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(processed_example["labels"].T)
plt.show()
# Out:
# time: 168 ms (started: 2023-08-01 19:55:32 +00:00)

# %%
dataset = dataset.map(prepare_dataset, remove_columns=dataset.column_names)
# Out:
# Map:   0%|          | 0/13154 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (649 > 600). Running this sequence through the model will result in indexing errors
# time: 12min 30s (started: 2023-08-01 19:55:32 +00:00)

# %%
def is_not_too_long(input_ids):
    input_length = len(input_ids)
    return input_length < 200


dataset = dataset.filter(is_not_too_long, input_columns=["input_ids"])
len(dataset)
# Out:
# Filter:   0%|          | 0/13154 [00:00<?, ? examples/s]
# 8227
# time: 983 ms (started: 2023-08-01 20:08:03 +00:00)

# %%
dataset = dataset.train_test_split(test_size=0.1)
# Out:
# time: 15.4 ms (started: 2023-08-01 20:08:04 +00:00)

# %%
from dataclasses import dataclass
from typing import Any, Dict, List, Union


@dataclass
class TTSDataCollatorWithPadding:
    processor: Any

    def __call__(
        self, features: List[Dict[str, Union[List[int], torch.Tensor]]]
    ) -> Dict[str, torch.Tensor]:
        input_ids = [{"input_ids": feature["input_ids"]} for feature in features]
        label_features = [{"input_values": feature["labels"]} for feature in features]
        speaker_features = [feature["speaker_embeddings"] for feature in features]

        # collate the inputs and targets into a batch
        batch = processor.pad(
            input_ids=input_ids, labels=label_features, return_tensors="pt"
        )

        # replace padding with -100 to ignore loss correctly
        batch["labels"] = batch["labels"].masked_fill(
            batch.decoder_attention_mask.unsqueeze(-1).ne(1), -100
        )

        # not used during fine-tuning
        del batch["decoder_attention_mask"]

        # round down target lengths to multiple of reduction factor
        if model.config.reduction_factor > 1:
            target_lengths = torch.tensor(
                [len(feature["input_values"]) for feature in label_features]
            )
            target_lengths = target_lengths.new(
                [
                    length - length % model.config.reduction_factor
                    for length in target_lengths
                ]
            )
            max_length = max(target_lengths)
            batch["labels"] = batch["labels"][:, :max_length]

        # also add in the speaker embeddings
        batch["speaker_embeddings"] = torch.tensor(speaker_features)

        return batch
# Out:
# time: 1.6 ms (started: 2023-08-01 20:08:04 +00:00)

# %%
data_collator = TTSDataCollatorWithPadding(processor=processor)
# Out:
# time: 259 µs (started: 2023-08-01 20:08:04 +00:00)

# %%
from transformers import SpeechT5ForTextToSpeech

model = SpeechT5ForTextToSpeech.from_pretrained(checkpoint)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/585M [00:00<?, ?B/s]
# time: 4.22 s (started: 2023-08-01 20:08:04 +00:00)

# %%
from functools import partial

# disable cache during training since it's incompatible with gradient checkpointing
model.config.use_cache = False

# set language and task for generation and re-enable cache
model.generate = partial(model.generate, use_cache=True)
# Out:
# time: 467 µs (started: 2023-08-01 20:08:08 +00:00)

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="speecht5_finetuned_voxpopuli_es_20k_steps",  # change to a repo name of your choice
    per_device_train_batch_size=8,
    gradient_accumulation_steps=1,
    learning_rate=3e-5,
    warmup_steps=100,
    max_steps=20000,
    gradient_checkpointing=True,
    fp16=True,
    evaluation_strategy="steps",
    per_device_eval_batch_size=4,
    save_steps=5000,
    eval_steps=5000,
    logging_steps=5000,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    greater_is_better=False,
    label_names=["labels"],
    push_to_hub=True,
)
# Out:
# time: 24.1 ms (started: 2023-08-01 20:09:35 +00:00)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    data_collator=data_collator,
    tokenizer=processor,
)
# Out:
# Cloning https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps into local empty directory.
# time: 5.18 s (started: 2023-08-01 20:09:40 +00:00)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='20000' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20000/20000 1:46:37, Epoch 21/22]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5000</td>
#       <td>0.492800</td>
#       <td>0.437751</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.456700</td>
#       <td>0.433196</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.445600</td>
#       <td>0.432302</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.439400</td>
#       <td>0.430935</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=20000, training_loss=0.45865491943359377, metrics={'train_runtime': 6399.4531, 'train_samples_per_second': 25.002, 'train_steps_per_second': 3.125, 'total_flos': 2.491260427573632e+16, 'train_loss': 0.45865491943359377, 'epoch': 21.6})
# time: 1h 46min 39s (started: 2023-08-01 20:09:45 +00:00)

# %%
trainer.push_to_hub()
# Out:
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 1.00/551M [00:00<?, ?B/s]
# Upload file runs/Aug01_20-09-35_f98a2314ad2b/events.out.tfevents.1690920585.f98a2314ad2b.303.0:   0%|         …
# To https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps
#    44d3f52..47bd5fc  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps
#    44d3f52..47bd5fc  main -> main
#
# To https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps
#    47bd5fc..ee2ddbb  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps
#    47bd5fc..ee2ddbb  main -> main
# 'https://huggingface.co/DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps/commit/47bd5fca594b7da628f48e9bc0d5898ac2fdfe2b'
# time: 1min 20s (started: 2023-08-01 21:56:25 +00:00)

# %%
model = SpeechT5ForTextToSpeech.from_pretrained("DrishtiSharma/speecht5_finetuned_voxpopuli_es_20k_steps")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/578M [00:00<?, ?B/s]
# time: 36.1 s (started: 2023-08-01 21:59:54 +00:00)

# %%
example = dataset["test"][304]
speaker_embeddings = torch.tensor(example["speaker_embeddings"]).unsqueeze(0)
speaker_embeddings.shape
# Out:
# torch.Size([1, 512])
# time: 28.2 ms (started: 2023-08-01 22:00:30 +00:00)

# %%
text = "Hola! Mi nombre es Drishti. Amo a mi familia"
# Out:
# time: 263 µs (started: 2023-08-01 22:00:30 +00:00)

# %%
tokenizer.decode(tokenizer(text)["input_ids"])
# Out:
# 'Hola! Mi nombre es Drishti. Amo a mi familia</s>'
# time: 3.48 ms (started: 2023-08-01 22:02:27 +00:00)

# %%
inputs = processor(text=text, return_tensors="pt")
# Out:
# time: 2.05 ms (started: 2023-08-01 22:02:40 +00:00)

# %%
spectrogram = model.generate_speech(inputs["input_ids"], speaker_embeddings)
# Out:
# time: 1.04 s (started: 2023-08-01 22:02:51 +00:00)

# %%
spectrogram
# Out:
# tensor([[-3.6022, -3.4662, -3.3304,  ..., -3.6805, -3.7591, -3.7990],
#         [-3.6718, -3.5220, -3.3871,  ..., -3.7324, -3.7528, -3.8528],
#         [-3.7145, -3.4956, -3.3644,  ..., -3.9099, -4.0046, -4.1550],
#         ...,
#         [-3.1858, -3.0118, -2.8884,  ..., -4.1932, -4.2453, -4.3337],
#         [-3.2166, -3.0379, -2.8517,  ..., -3.9399, -4.0040, -4.1047],
#         [-3.2012, -3.0102, -2.8815,  ..., -3.8445, -3.9113, -4.0136]])
# time: 5.83 ms (started: 2023-08-01 22:03:04 +00:00)

# %%
from transformers import SpeechT5HifiGan
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/50.7M [00:00<?, ?B/s]
# time: 2.07 s (started: 2023-08-01 22:04:17 +00:00)

# %%
with torch.no_grad():
    speech = vocoder(spectrogram)
# Out:
# time: 217 ms (started: 2023-08-01 22:04:22 +00:00)

# %%
from IPython.display import Audio
Audio(speech.numpy(), rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# time: 13.9 ms (started: 2023-08-01 22:04:48 +00:00)

# %%
# !git config --global user.email "driknowsnothing@gmail.com"
# !git config --global user.name "DrishtiShrrrma"
# Out:
# time: 207 ms (started: 2023-08-01 22:05:00 +00:00)

# %%
# !git clone https://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@github.com/DrishtiShrrrma/speechT5-spanish-tts.git
# Out:
# Cloning into 'speechT5-spanish-tts'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 4), reused 2 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 1.31 MiB | 18.13 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# time: 1.21 s (started: 2023-08-01 22:05:09 +00:00)

# %%
# %cd speechT5-spanish-tts
# Out:
# /content/speechT5-spanish-tts
# time: 2.52 ms (started: 2023-08-01 22:19:31 +00:00)

# %%
# !mkdir -p 20kstepsfp16bs8
# Out:
# time: 103 ms (started: 2023-08-01 22:20:28 +00:00)

# %%
# !cp -r /content/speecht5_finetuned_voxpopuli_es_20k_steps ./20kstepsfp16bs8
# Out:
# time: 21.2 s (started: 2023-08-01 22:21:12 +00:00)

# %%
# !git add .
# Out:
# warning: adding embedded git repository: 20kstepsfp16bs8/speecht5_finetuned_voxpopuli_es_20k_steps
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> 20kstepsfp16bs8/speecht5_finetuned_voxpopuli_es_20k_steps
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached 20kstepsfp16bs8/speecht5_finetuned_voxpopuli_es_20k_steps
# hint:
# hint: See "git help submodule" for more information.
# time: 104 ms (started: 2023-08-01 22:21:47 +00:00)

# %%
# !git commit -m "Add model weights to myfolder"
# Out:
# [main 5740ab8] Add model weights to myfolder
#  1 file changed, 1 insertion(+)
#  create mode 160000 20kstepsfp16bs8/speecht5_finetuned_voxpopuli_es_20k_steps
# time: 104 ms (started: 2023-08-01 22:22:16 +00:00)

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# time: 3.21 s (started: 2023-08-01 22:22:35 +00:00)

# %%
# !git push
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
# time: 607 ms (started: 2023-08-01 22:23:34 +00:00)

# %%
# !git config --get remote.origin.url
# Out:
# https://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@github.com/DrishtiShrrrma/speechT5-spanish-tts.git
# time: 104 ms (started: 2023-08-01 22:24:19 +00:00)

# %%
# !git remote set-url origin git@github.com:DrishtiShrrrma/speechT5-spanish-tts.git
# Out:
# time: 104 ms (started: 2023-08-01 22:25:18 +00:00)

# %%
# !git remote -v
# Out:
# origin	git@github.com:DrishtiShrrrma/speechT5-spanish-tts.git (fetch)
# origin	git@github.com:DrishtiShrrrma/speechT5-spanish-tts.git (push)
# time: 105 ms (started: 2023-08-01 22:26:22 +00:00)

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# time: 105 ms (started: 2023-08-01 22:27:08 +00:00)

# %%
# !git push origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# time: 806 ms (started: 2023-08-01 22:28:01 +00:00)

# %%
# !git add .
# !git commit -m "Your commit message"
